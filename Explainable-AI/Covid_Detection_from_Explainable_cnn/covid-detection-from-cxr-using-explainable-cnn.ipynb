# %%
import tensorflow
from PIL import Image
import glob
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, save_img, img_to_array
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adamax
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam,Adadelta,RMSprop,Adagrad
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,EarlyStopping
from tensorflow.keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import numpy as np
import argparse
import cv2
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from tensorflow.keras.models import Model, Sequential
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
import scipy
import skimage
from skimage.transform import resize
import random
from PIL import Image
import glob
from tensorflow.keras.preprocessing.image import load_img, save_img, img_to_array
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adamax
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam,Adadelta,RMSprop,Adagrad
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import numpy as np
import argparse
import cv2
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from tensorflow.keras.models import Model, Sequential
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
import scipy
import skimage
from skimage.transform import resize
import random
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0771-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0421-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0531-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0416-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0627-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0757-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0696-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0808-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0101-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0304-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0385-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0908-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0428-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0399-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0461-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0013-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0103-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0460-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0490-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0505-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0555-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0875-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0950-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0927-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0619-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0393-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0447-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0853-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0526-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0723-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0640-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0419-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0525-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0690-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0298-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0137-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0283-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0695-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0900-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0481-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0009-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0160-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0318-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0460-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0402-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0453-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0523-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0824-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0317-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0626-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0499-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0892-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0091-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0668-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0650-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0070-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0649-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0509-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0439-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0242-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0059-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0910-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0502-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0067-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0507-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0364-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0645-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0363-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0381-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0308-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0471-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0587-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0526-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0873-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0525-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0302-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0809-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0555-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0539-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0097-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0906-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0609-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0492-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0652-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0347-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0458-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0481-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0401-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0838-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0930-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0962-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0993-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0960-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0505-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0337-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0533-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0651-0004.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0846-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0499-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0424-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0015-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0329-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0907-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0435-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0133-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0877-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0491-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0372-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0513-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0611-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0852-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0517-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0170-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0041-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0361-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0414-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0408-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0326-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0956-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0820-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0814-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0655-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0520-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0084-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0413-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0848-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0154-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0249-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0588-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0659-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0500-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0388-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0377-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0437-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0467-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0305-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0665-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0265-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0976-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0727-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0926-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0451-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0917-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0427-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0430-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0898-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0389-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0151-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0533-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0414-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0488-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0511-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0493-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0444-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0243-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0535-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0029-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0519-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0618-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0081-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0439-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0375-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0519-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0629-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0812-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0110-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0420-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0035-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0987-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0421-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0882-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0164-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0897-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0602-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0395-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0983-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0634-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0815-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0851-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0408-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0862-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0523-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0523-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0349-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0879-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0803-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0395-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0251-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0988-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0571-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0913-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0522-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0512-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0379-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0831-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0589-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0692-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0410-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0874-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0105-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0693-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0241-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0403-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0790-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0585-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0776-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0797-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0383-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0306-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0021-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0395-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0942-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0416-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0700-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0182-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0515-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0510-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0384-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0833-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0396-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0663-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0403-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0033-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0651-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0425-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0168-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0935-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0843-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0863-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0367-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0730-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0774-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0887-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0245-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0563-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0517-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0834-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0424-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0811-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0374-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0235-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0432-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0744-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0351-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0899-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0497-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0983-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0807-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0793-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0974-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0967-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0003-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0604-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0177-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0237-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0368-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0888-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0947-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0107-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0683-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0438-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0528-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0017-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0736-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0210-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0881-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0486-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0678-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0951-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0346-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0149-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0319-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0386-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0489-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0006-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0529-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0554-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0781-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0859-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0718-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0187-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0383-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0558-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0946-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0821-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0804-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0488-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0371-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0765-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0981-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0567-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0509-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0922-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0043-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0858-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0496-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0387-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0388-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0061-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0456-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0111-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0286-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0854-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0630-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0435-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0404-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0653-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0603-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0467-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0516-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0905-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0934-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0851-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0465-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0753-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0517-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0127-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0525-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0799-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0191-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0633-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0341-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0102-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0689-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0467-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0391-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0071-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0661-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0520-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0530-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0497-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0480-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0207-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0971-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0206-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0513-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0397-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0636-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0536-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0031-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0856-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0989-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0579-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0508-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0490-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0449-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0289-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0749-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0437-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0529-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0195-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0519-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0886-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0904-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0553-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0865-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0933-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0871-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0521-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0495-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0050-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0416-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0561-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0780-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0961-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0339-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0450-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0418-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0925-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0890-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0971-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0046-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0385-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0239-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0667-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0384-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0666-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0011-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0826-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0936-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0501-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0005-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0453-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0213-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0966-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0338-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0507-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0392-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0621-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0404-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0036-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0673-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0491-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0501-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0425-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0643-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0847-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0016-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0518-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0986-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0796-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0489-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0030-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0393-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0503-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0332-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0466-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0478-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0707-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0468-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0511-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0818-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0868-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0025-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0587-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0399-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0229-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0185-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0434-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0037-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0552-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0485-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0099-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0083-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0521-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0620-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0514-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0648-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0924-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0007-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0439-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0775-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0391-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0307-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0039-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0027-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0500-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0477-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0257-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0365-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0458-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0616-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0499-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0686-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0077-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0540-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0089-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0637-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0499-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0033-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0128-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0825-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0428-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0240-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0410-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0311-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0350-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0487-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0019-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0832-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0798-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0359-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0327-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0011-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0491-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0109-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0462-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0300-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0527-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0476-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0509-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0525-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0303-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0622-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0555-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0601-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0746-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0049-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0180-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0827-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0093-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0358-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0511-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0496-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0406-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0119-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0669-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0600-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0023-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0417-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0594-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0183-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0482-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0719-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0325-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0772-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0896-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0172-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0572-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0647-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0810-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0511-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0642-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0455-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0641-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0390-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0445-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0509-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0855-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0839-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0576-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0599-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0504-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0537-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0491-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0400-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0528-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0945-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0264-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0535-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0851-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0482-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0497-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0501-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0623-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0568-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0524-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0617-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0841-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0535-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0011-0001-0002.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0312-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0530-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0473-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0362-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0505-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0293-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0508-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0115-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0409-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0531-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0433-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/IM-0497-0001-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0923-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0918-0001.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/F051E018-DAD1-4506-AD43-BE4CA29E960B.jpeg
# ...
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person515_virus_1032.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person69_virus_129.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person110_virus_207.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person573_virus_1116.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person457_virus_944.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1441_virus_2457.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person54_virus_109.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person442_virus_898.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person405_virus_805.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person585_virus_1129.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person633_virus_1213.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person460_virus_948.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person330_virus_683.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person348_virus_714.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person599_virus_1155.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person379_virus_762.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1366_virus_2349.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person432_virus_881.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1214_virus_2059.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1298_virus_2228.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person716_virus_1314.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person454_virus_938.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1284_virus_2207.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1387_virus_2382.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person637_virus_1218.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1238_virus_2098.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person947_virus_1618.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person967_virus_1640.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person615_virus_1184.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person346_virus_709.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person71_virus_132.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person562_virus_1102.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1249_virus_2118.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1374_virus_2365.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person512_virus_1029.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1217_virus_2063.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person705_virus_1302.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person34_virus_76.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person57_virus_113.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1355_virus_2336.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person343_virus_704.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1350_virus_2329.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person940_virus_1609.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person407_virus_811.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person124_virus_242.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person738_virus_1360.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person508_virus_1020.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person617_virus_1187.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person508_virus_1021.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person711_virus_1309.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person621_virus_1195.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person765_virus_1393.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person558_virus_1098.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person925_virus_1582.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1358_virus_2339.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person586_virus_1130.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1651_virus_2855.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1_virus_9.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1311_virus_2257.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person739_virus_1361.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1300_virus_2240.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person115_virus_218.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1424_virus_2437.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1224_virus_2074.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1336_virus_2306.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person591_virus_1139.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person120_virus_226.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person407_virus_814.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1258_virus_2138.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person433_virus_882.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person461_virus_949.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1653_virus_2859.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person463_virus_953.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1323_virus_2283.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person348_virus_721.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person368_virus_748.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1319_virus_2276.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1418_virus_2429.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person388_virus_777.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person348_virus_719.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person688_virus_1282.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person399_virus_793.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person396_virus_789.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person119_virus_225.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person441_virus_895.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person389_virus_778.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person949_virus_1620.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person779_virus_1409.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1383_virus_2377.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1360_virus_2341.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person926_virus_1583.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person445_virus_919.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person328_virus_681.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person605_virus_1169.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person376_virus_759.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1213_virus_2058.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person699_virus_1295.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person39_virus_85.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1309_virus_2254.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1643_virus_2843.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1345_virus_2321.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1182_virus_2017.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1389_virus_2387.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person124_virus_245.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person574_virus_1118.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person950_virus_1621.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person108_virus_201.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1243_virus_2110.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person503_virus_1013.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person348_virus_717.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1627_virus_2819.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person354_virus_729.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1662_virus_2875.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person387_virus_772.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person102_virus_189.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person67_virus_126.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person459_virus_947.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person118_virus_224.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person614_virus_1183.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person124_virus_234.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person924_virus_1581.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person348_virus_716.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person409_virus_818.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1233_virus_2090.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1286_virus_2209.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person734_virus_1355.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person684_virus_1275.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1669_virus_2885.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person509_virus_1025.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1254_virus_2130.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person37_virus_82.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1235_virus_2095.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person722_virus_1341.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person324_virus_658.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person107_virus_197.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person327_virus_679.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person622_virus_1196.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person374_virus_757.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1448_virus_2468.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person502_virus_1012.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person557_virus_1097.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person117_virus_223.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person720_virus_1339.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person487_virus_991.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person456_virus_943.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person681_virus_1272.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1211_virus_2056.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person22_virus_54.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person400_virus_794.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person105_virus_193.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person414_virus_845.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person960_virus_1633.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person348_virus_720.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1324_virus_2284.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1184_virus_2019.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person445_virus_917.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person408_virus_815.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1_virus_8.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1376_virus_2367.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person124_virus_240.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1253_virus_2129.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person918_virus_1575.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1307_virus_2251.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1361_virus_2342.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1655_virus_2861.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1290_virus_2216.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1316_virus_2271.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person401_virus_795.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person434_virus_883.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person588_virus_1134.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1180_virus_2015.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1439_virus_2453.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person109_virus_203.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1261_virus_2147.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person1664_virus_2877.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person103_virus_190.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person124_virus_231.jpeg
# /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person931_virus_1592.jpeg

# %%
def Images_details_Print_data(data, path):
    print(" ====== Images in: ", path)    
    for k, v in data.items():
        print("%s:\t%s" % (k, v))

def Images_details(path):
    files = [f for f in glob.glob(path + "**/*.*", recursive=True)]
    data = {}
    data['images_count'] = len(files)
    data['min_width'] = 10**100  # No image will be bigger than that
    data['max_width'] = 0
    data['min_height'] = 10**100  # No image will be bigger than that
    data['max_height'] = 0


    for f in files:
        im = Image.open(f)
        width, height = im.size
        data['min_width'] = min(width, data['min_width'])
        data['max_width'] = max(width, data['max_height'])
        data['min_height'] = min(height, data['min_height'])
        data['max_height'] = max(height, data['max_height'])

    Images_details_Print_data(data, path)

# %%
COV_DIR = "/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/covid/"
NORM_DIR = "/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/"
VIR_DIR = "/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/"

# %%
Images_details(NORM_DIR)
# Out:
#  ====== Images in:  /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/
# images_count:	668
# min_width:	1040
# max_width:	2628
# min_height:	650
# max_height:	2628

# %%
Images_details(COV_DIR)
# Out:
#  ====== Images in:  /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/covid/
# images_count:	536
# min_width:	240
# max_width:	4095
# min_height:	237
# max_height:	4095

# %%
Images_details(VIR_DIR)
# Out:
#  ====== Images in:  /kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/
# images_count:	619
# min_width:	384
# max_width:	2304
# min_height:	127
# max_height:	2304

# %%
Cimages = os.listdir(COV_DIR)
Nimages = os.listdir(NORM_DIR)
Vimages = os.listdir(VIR_DIR)

# %%
sample_images = random.sample(Cimages,6)
f,ax = plt.subplots(2,3,figsize=(15,9))

for i in range(0,6):
    im = cv2.imread('/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/covid/'+sample_images[i])
    ax[i//3,i%3].imshow(im)
    ax[i//3,i%3].axis('off')
f.suptitle('COVID-19 affected Chest X-Ray',fontsize=20)
plt.show()

# %%
sample_images = random.sample(Vimages,6)
f,ax = plt.subplots(2,3,figsize=(15,9))

for i in range(0,6):
    im = cv2.imread('/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/'+sample_images[i])
    ax[i//3,i%3].imshow(im)
    ax[i//3,i%3].axis('off')
f.suptitle('Viral Infection affected Chest X-Ray',fontsize=20)
plt.show()

# %%
sample_images = random.sample(Nimages,6)
f,ax = plt.subplots(2,3,figsize=(15,9))

for i in range(0,6):
    im = cv2.imread('/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/'+sample_images[i])
    ax[i//3,i%3].imshow(im)
    ax[i//3,i%3].axis('off')
f.suptitle('Normal Chest X-Ray',fontsize=20)
plt.show()

# %% [markdown]
# ### Observation:
#
# From the above sample images we can easily observed that:
# - Normal CXR Images have clear lungs.
# - Viral Infection CXR Images have slight congestion in lungs
# - COVID-19 images have serious congestion in lungs

# %% [markdown]
# ## Image Enhancement (White Balance and CLAHE)
#
# This Kernel is inspired from  [COVIDLite](https://arxiv.org/pdf/2006.13873.pdf) Paper published in arXiv. In this paper authors have used White Balance and CLAHE as a image preprocessing step for detection of COVID-19 cases.
#
# ### 1. White Balance
#
# White Balance is the image processing operation applied to adjust proper color fidelity in a digital image. Due to low lighting conditions in medical images, some of the parts of the image appeared dark and the image capturing equipment does not detect light precisely as the human eye does.
#
# Due to this, image processing or correction help to ensure that the final image represents the colors of the natural image. The objective of this operation is to enhance the visibility of the image so that Deep CNNs could extract useful features from the image. The white balance algorithm adjusts the colors of the active layers of the image by stretching red, green, and blue channels independently.
#
# For doing this, pixel colors discarded, which are at the end of the three channels and are used by only 0.05% of the pixels in the image, while stretching is performed for the remaining color range.
#
#  After this operation, pixel colors infrequently present at the end of the channel could not negatively influence the upper and lower bound values while stretching. In this solution, we have implemented a white balance algorithm in python language using NumPy and OpenCV library.
#
# The steps of the White balance algorithm can be summarized as:
#
# ![](https://i.ibb.co/1rR3h7v/white-balance.png)
#
# where Pi(C) represents the taking the ith percentile of channel C, and Clip(., min, max) operation depicts performing saturation operation within min and max values. C, Cupd denotes the input and updated channels pixel values after the operation respectively.
#
# ### 2. CLAHE (Contrast Limited Adaptive Histogram Equalization)
#
# It is an effective contrast enhancement method that effectively increases the contrast of the image. CLAHE is an improved version of the adaptivehistogram equation (AHE).
#
# Histogram equalization is the simple method for enhancing the contrast of the image by spreading out the intensity range of the image or stretching out the most frequent intensity value of the image. Stretching the intensity values changes the natural brightness of the input image and introduces some undesirable noise in the image.
#
# In AHE, the input image split into several small images, also known as tiles. In this method, the histogram of each tile computed, which corresponds to different sections of the image and uses them to derive intensity remapping function for each tile.
# This method introduces noise in the image due to over amplification. CLAHE works precisely the same as AHE, but it clips the histogram at specific values for limiting the amplification before computing the cumulative distributive function.
#
# The overamplified part of the histogram is further redistributed over the histogram. In one of the previous studies, CLAHE showed exceptional results in enhancing chest CT images and considered useful in examining a wide variety of medical images. The computation of CLAHE is performed as:
#
# ![](https://i.ibb.co/MSM3MrN/CL1.png)
#
# where, p represents pixel value after applying CLAHE, pmax , pmin represents maximum and minimum pixel value of an image respectively and P(f) represents cumulative probability distribution function.
#
# ![](https://i.ibb.co/DMkncVP/CLAHE.png)

# %%
## Enhancing the CXR Images using White balance and CLAHE

def wb(channel, perc = 0.05):
    mi, ma = (np.percentile(channel, perc), np.percentile(channel,100.0-perc))
    channel = np.uint8(np.clip((channel-mi)*255.0/(ma-mi), 0, 255))
    return channel

# %% [markdown]
# ## Data preparation

# %%
data=[]
labels=[]
Uninfected=os.listdir("/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/")
for a in Uninfected:
	# extract the class label from the filename
	

	# load the image, swap color channels, and resize it to be a fixed
	# 224x224 pixels while ignoring aspect ratio
	image = cv2.imread("/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/"+a)
	imWB  = np.dstack([wb(channel, 0.05) for channel in cv2.split(image)] )
	gray_image = cv2.cvtColor(imWB, cv2.COLOR_BGR2GRAY)
	clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(16, 16))
	img_clahe1 = clahe.apply(gray_image)
	img = cv2.cvtColor(img_clahe1, cv2.COLOR_GRAY2RGB)
	image = cv2.resize(img, (224, 224))

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(0)

Covid=os.listdir("/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/covid/")
for b in Covid:
	# extract the class label from the filename
	

	# load the image, swap color channels, and resize it to be a fixed
	# 224x224 pixels while ignoring aspect ratio
	image = cv2.imread("/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/covid/"+b)
	imWB  = np.dstack([wb(channel, 0.05) for channel in cv2.split(image)] )
	gray_image = cv2.cvtColor(imWB, cv2.COLOR_BGR2GRAY)
	clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(16, 16))
	img_clahe1 = clahe.apply(gray_image)
	img = cv2.cvtColor(img_clahe1, cv2.COLOR_GRAY2RGB)
	image = cv2.resize(img, (224, 224))
	# update the data and labels lists, respectively
	data.append(image)
	labels.append(1)
 
Virus=os.listdir("/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/")
for c in Virus:
	# extract the class label from the filename
	

	# load the image, swap color channels, and resize it to be a fixed
	# 224x224 pixels while ignoring aspect ratio
	image = cv2.imread("/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/"+c)
	imWB  = np.dstack([wb(channel, 0.05) for channel in cv2.split(image)] )
	gray_image = cv2.cvtColor(imWB, cv2.COLOR_BGR2GRAY)
	clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(16, 16))
	img_clahe1 = clahe.apply(gray_image)
	img = cv2.cvtColor(img_clahe1, cv2.COLOR_GRAY2RGB)
	image = cv2.resize(img, (224, 224))

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(2)

# %% [markdown]
# ## Image normalization

# %%
# data normalization by dividing image pixels by 255
data = np.array(data) / 255.0
labels = np.array(labels)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
(trainX, testX, trainY, testY) = train_test_split(data, labels,stratify=labels,
	test_size=0.20,  random_state=42)

# %%
trainAug  = ImageDataGenerator(
	rotation_range=15,
	fill_mode="nearest")

# %% [markdown]
# ## Model Building
#
# In this kernel I will be using Depthwise separable CNNs

# %%
inputs = Input(shape=(224, 224,3))
# First conv block
x = Conv2D(filters=4, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
x = Conv2D(filters=4, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPool2D(pool_size=(2, 2))(x)

# second conv block
x = Conv2D(filters=8, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
x = Conv2D(filters=8, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPool2D(pool_size=(2, 2))(x)

# third conv block
x = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
x = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPool2D(pool_size=(2, 2))(x)


# first separable conv block
x = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)


# second separable conv block
x = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)


# third separable conv block
x = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)
x = Dropout(rate=0.2)(x)

# fourth separable conv block
x = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)
x = Dropout(rate=0.2)(x)


# fifth separable conv block
x = SeparableConv2D(filters=512, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=512, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)
x = Dropout(rate=0.2)(x)

# FC layer
x = Flatten()(x)
x = Dense(units=512, activation='relu')(x)
x = Dropout(rate=0.7)(x)
x = Dense(units=128, activation='relu')(x)
x = Dropout(rate=0.5)(x)
x = Dense(units=64, activation='relu')(x)
x = Dropout(rate=0.3)(x)
x = Dense(units=32, activation='relu')(x)
x = Dropout(rate=0.3)(x)

# Output layer
output = Dense(units=3, activation='softmax')(x)

# Creating model and compiling
model = Model(inputs=inputs, outputs=output)

EPOCHS = 50
BS = 16


# compile our model
print("[INFO] compiling model...")
opt = "adam"
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
callbacks = [ModelCheckpoint('.mdl_wts.hdf5', monitor='val_loss', save_best_only=True),
             EarlyStopping(monitor='val_loss', patience=5)]
model.summary()
# Out:
# [INFO] compiling model...
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 224, 224, 16)      448
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 224, 224, 16)      2320
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# separable_conv2d_32 (Separab (None, 112, 112, 32)      688
# _________________________________________________________________
# separable_conv2d_33 (Separab (None, 112, 112, 32)      1344
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 112, 112, 32)      128
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# separable_conv2d_34 (Separab (None, 56, 56, 64)        2400
# _________________________________________________________________
# separable_conv2d_35 (Separab (None, 56, 56, 64)        4736
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# separable_conv2d_36 (Separab (None, 28, 28, 128)       8896
# _________________________________________________________________
# separable_conv2d_37 (Separab (None, 28, 28, 128)       17664
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# separable_conv2d_38 (Separab (None, 14, 14, 256)       34176
# _________________________________________________________________
# separable_conv2d_39 (Separab (None, 14, 14, 256)       68096
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 14, 14, 256)       1024
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# separable_conv2d_40 (Separab (None, 7, 7, 512)         133888
# _________________________________________________________________
# separable_conv2d_41 (Separab (None, 7, 7, 512)         267264
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               2359808
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 2,981,795
# Trainable params: 2,979,811
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
BS = 16
print("[INFO] training head...")
H = model.fit_generator(
	trainAug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,callbacks=callbacks)
# Out:
# [INFO] training head...
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 91/91 [==============================] - 19s 185ms/step - loss: 1.0955 - accuracy: 0.3453 - val_loss: 1.1340 - val_accuracy: 0.2932
# Epoch 2/50
# 91/91 [==============================] - 16s 179ms/step - loss: 0.9307 - accuracy: 0.6214 - val_loss: 1.2381 - val_accuracy: 0.2932
# Epoch 3/50
# 91/91 [==============================] - 17s 186ms/step - loss: 0.6068 - accuracy: 0.7638 - val_loss: 1.1382 - val_accuracy: 0.2932
# Epoch 4/50
# 91/91 [==============================] - 17s 190ms/step - loss: 0.4682 - accuracy: 0.8515 - val_loss: 1.1249 - val_accuracy: 0.3671
# Epoch 5/50
# 91/91 [==============================] - 16s 178ms/step - loss: 0.5264 - accuracy: 0.8490 - val_loss: 1.0528 - val_accuracy: 0.5973
# Epoch 6/50
# 91/91 [==============================] - 17s 181ms/step - loss: 0.4332 - accuracy: 0.8518 - val_loss: 0.8635 - val_accuracy: 0.8274
# Epoch 7/50
# 91/91 [==============================] - 17s 186ms/step - loss: 0.3817 - accuracy: 0.8849 - val_loss: 0.5697 - val_accuracy: 0.8685
# Epoch 8/50
# 91/91 [==============================] - 18s 193ms/step - loss: 0.3634 - accuracy: 0.8771 - val_loss: 1.7097 - val_accuracy: 0.4110
# Epoch 9/50
# 91/91 [==============================] - 17s 187ms/step - loss: 0.3100 - accuracy: 0.9007 - val_loss: 2.4232 - val_accuracy: 0.3945
# Epoch 10/50
# 91/91 [==============================] - 18s 193ms/step - loss: 0.3289 - accuracy: 0.8865 - val_loss: 0.8488 - val_accuracy: 0.6658
# Epoch 11/50
# 91/91 [==============================] - 16s 180ms/step - loss: 0.2665 - accuracy: 0.9274 - val_loss: 0.2152 - val_accuracy: 0.9260
# Epoch 12/50
# 91/91 [==============================] - 17s 187ms/step - loss: 0.2684 - accuracy: 0.9188 - val_loss: 0.2246 - val_accuracy: 0.9288
# Epoch 13/50
# 91/91 [==============================] - 17s 189ms/step - loss: 0.2680 - accuracy: 0.9151 - val_loss: 0.6588 - val_accuracy: 0.7041
# Epoch 14/50
# 91/91 [==============================] - 18s 192ms/step - loss: 0.2427 - accuracy: 0.9238 - val_loss: 0.4625 - val_accuracy: 0.7808
# Epoch 15/50
# 91/91 [==============================] - 16s 174ms/step - loss: 0.2498 - accuracy: 0.9274 - val_loss: 0.9750 - val_accuracy: 0.7151
# Epoch 16/50
# 91/91 [==============================] - 17s 185ms/step - loss: 0.2192 - accuracy: 0.9369 - val_loss: 1.9695 - val_accuracy: 0.6575

# %% [markdown]
# ## Model Evaluation

# %%
## Loading best model based on its weights

from numpy import loadtxt
from tensorflow.keras.models import load_model
model = load_model('.mdl_wts.hdf5')
score = model.evaluate(testX, testY,verbose=1)

print(score)
# Out:
# 12/12 [==============================] - 1s 19ms/step - loss: 0.2152 - accuracy: 0.9260
# [0.21515707671642303, 0.9260274171829224]

# %%
import itertools
pred_Y = model.predict(testX, batch_size = 8, verbose = True)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    target_names =['Normal','Covid','Virus']

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(testX, batch_size=BS)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(pred_Y,axis = 1) 
# Convert validation observations to one hot vectors
# compute the confusion matrix
confusion_mtx = confusion_matrix(testY, Y_pred_classes)

 

# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(3))
# Out:
# 46/46 [==============================] - 0s 6ms/step

# %% [markdown]
# ## Classification Report

# %%
predIdxs = model.predict(testX, batch_size=BS)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)


# show a nicely formatted classification report
print(classification_report(testY, predIdxs,target_names=['normal','covid','virus']))
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.87      0.98      0.92       134
#        covid       0.95      0.98      0.97       107
#        virus       0.98      0.82      0.89       124
#
#     accuracy                           0.93       365
#    macro avg       0.93      0.93      0.93       365
# weighted avg       0.93      0.93      0.93       365

# %% [markdown]
# ## Plotting ROC-AUC Curve

# %%
import seaborn as sns
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_test = pd.get_dummies(testY)
y_test = np.array(y_test)

n_classes = 3


# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred_Y[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    # Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred_Y.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
# Plot of a ROC curve for a specific class
for i in range(n_classes):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
fig = plt.figure(figsize=(12, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))


plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
sns.despine()
plt.show()

# %%
def specificity(y_true, y_pred):
    """
    param:
    y_pred - Predicted labels
    y_true - True labels 
    Returns:
    Specificity score
    """
    neg_y_true = 1 - y_true
    neg_y_pred = 1 - y_pred
    fp = K.sum(neg_y_true * y_pred)
    tn = K.sum(neg_y_true * neg_y_pred)
    specificity = tn / (tn + fp + K.epsilon())
    return specificity

# %%
print(specificity(y_test, Y_pred))
# Out:
# tf.Tensor(0.93566626, shape=(), dtype=float32)

# %% [markdown]
# ## Plotting Model Prediction

# %%
# getting predictions on val set.
pred=model.predict(testX, batch_size=BS)
Y_pred_classes=np.argmax(pred,axis=1)

Y_true = np.argmax(testY,axis = 0) 

# Mapping Classes
classes = {0 : 'Normal',
            1 : 'COVID',
            2 : 'Viral'}

# %%
incorrect = []
for i in range(len(testY)):
    if(not Y_pred_classes[i] == testY[i]):
        incorrect.append(i)
    if(len(incorrect) == 22):
        break

correct = []
for i in range(len(testY)):
    if(Y_pred_classes[i] == testY[i]):
        correct.append(i)
    if(len(correct) == 100):
        break

# %%
fig, ax = plt.subplots(4,2, figsize=(12,10))
fig.set_size_inches(10,10)
ax[0,0].imshow(testX[correct[0]], cmap='gray')
ax[0,0].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[0]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[0]]]))

ax[0,1].imshow(testX[correct[1]], cmap='gray')
ax[0,1].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[1]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[1]]]))
ax[1,0].imshow(testX[correct[2]], cmap='gray')
ax[1,0].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[2]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[2]]]))
ax[1,1].imshow(testX[correct[3]], cmap='gray')
ax[1,1].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[3]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[3]]]))
ax[2,0].imshow(testX[correct[4]], cmap='gray')
ax[2,0].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[4]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[4]]]))
ax[2,1].imshow(testX[correct[5]], cmap='gray')
ax[2,1].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[5]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[5]]]))
ax[3,0].imshow(testX[correct[6]], cmap='gray')
ax[3,0].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[6]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[6]]]))
ax[3,1].imshow(testX[correct[7]], cmap='gray')
ax[3,1].set_title("Predicted Label : " + str(classes[Y_pred_classes[correct[7]]]) + "\n"+"Actual Label : " + 
                 str(classes[testY[correct[7]]]))
fig.tight_layout(pad=1.0)
plt.show()

# %% [markdown]
# ## Model Explanation

# %% [markdown]
# Analyzing Correct predictions by Model Using LIME

# %%
import lime
from lime import lime_image

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(testX[correct[5]], model.predict, top_labels=5, hide_color=0, num_samples=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from skimage.segmentation import mark_boundaries
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ## GradCAM Heatmap

# %%
# !pip install tf-keras-vis
# Out:
# Requirement already satisfied: tf-keras-vis in /opt/conda/lib/python3.7/site-packages (0.7.2)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from tf-keras-vis) (2.9.0)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.7/site-packages (from tf-keras-vis) (2.5.0)
# Requirement already satisfied: deprecated in /opt/conda/lib/python3.7/site-packages (from tf-keras-vis) (1.2.12)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from tf-keras-vis) (1.6.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from tf-keras-vis) (20.9)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.7/site-packages (from tf-keras-vis) (8.2.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.7/site-packages (from deprecated->tf-keras-vis) (1.12.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from imageio->tf-keras-vis) (1.19.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->tf-keras-vis) (2.4.7)
# Requirement already satisfied: astunparse~=1.6.3 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (1.12)
# Requirement already satisfied: tensorboard~=2.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (2.5.0)
# Requirement already satisfied: grpcio~=1.34.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (1.34.1)
# Requirement already satisfied: h5py~=3.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (3.1.0)
# Requirement already satisfied: absl-py~=0.10 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (3.7.4.3)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (1.1.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (2.5.0.dev2021032900)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (3.17.3)
# Requirement already satisfied: gast==0.4.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (1.15.0)
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (0.36.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->tf-keras-vis) (3.3.0)
# Requirement already satisfied: cached-property in /opt/conda/lib/python3.7/site-packages (from h5py~=3.1.0->tensorflow->tf-keras-vis) (1.5.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (1.30.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (49.6.0.post20210108)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow->tf-keras-vis) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->tf-keras-vis) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->tf-keras-vis) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->tf-keras-vis) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->tf-keras-vis) (1.3.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow->tf-keras-vis) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->tf-keras-vis) (0.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->tf-keras-vis) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->tf-keras-vis) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->tf-keras-vis) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->tf-keras-vis) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->tf-keras-vis) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow->tf-keras-vis) (3.4.1)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tf_keras_vis.activation_maximization import ActivationMaximization
from tf_keras_vis.utils.callbacks import Print

# Define modifier to replace a softmax function of the last layer to a linear function.
def model_modifier(m):
    m.layers[-1].activation = tf.keras.activations.linear

# Create Activation Maximization object
activation_maximization = ActivationMaximization(model, model_modifier)

# Define loss function. 20 is the imagenet index corresponding to ouzel.
loss = lambda x: K.mean(x[:, 1])

# Generate max activation with debug printing
activation = activation_maximization(loss, callbacks=[Print(interval=100)])
image = activation[0].astype(np.uint8)

f, ax = plt.subplots(figsize=(10, 5), subplot_kw={'xticks': [], 'yticks': []})
ax.imshow(image)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated class PrintLogger. (Use `Progress` instead.) -- Deprecated since version 0.7.0.
# Steps: 100	Scores: [9205.1962890625],	Regularization: [('TotalVariation2D', [25.933780670166016]), ('Norm', [40.10874938964844])]
# Steps: 200	Scores: [6456.54296875],	Regularization: [('TotalVariation2D', [19.935205459594727]), ('Norm', [40.298439025878906])]

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import load_img

# Load images
img1 = load_img('/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/normal/NORMAL2-IM-0388-0001.jpeg', target_size=(224, 224))
img2 = load_img('/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/virus/person704_virus_1301.jpeg', target_size=(224, 224))
img3 = load_img('/kaggle/input/covid-cxr-image-dataset-research/COVID_IEEE/covid/covid1900167.png', target_size=(224, 224))

images = np.asarray([np.array(img1), np.array(img2),np.array(img3)])

# Prepare datasets
X = preprocess_input(images)

# Render
subprot_args = {
    'nrows': 1,
    'ncols': 3,
    'figsize': (6, 3),
    'subplot_kw': {'xticks': [], 'yticks': []}
}
f, ax = plt.subplots(**subprot_args)
for i in range(len(images)):
    ax[i].imshow(images[i])
plt.tight_layout()
plt.show()

# %%
# Define loss function. 1 is the imagenet index corresponding to Goldfish,
# And 294 is one corresponding to Bear.
def loss(output):
    return (output[1][1], output[0][1])

# Define modifier to replace a softmax function of the last layer to a linear function.
def model_modifier(m):
    m.layers[-1].activation = tf.keras.activations.linear
    return m

# %%
from matplotlib import cm
from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.utils import normalize

# Create Gradcam object
gradcam = Gradcam(model, model_modifier, clone=False)

# Generate heatmap with GradCAM
cam = gradcam(loss, X)
cam = normalize(cam)

f, ax = plt.subplots(**subprot_args)
for i in range(len(cam)):
    heatmap = np.uint8(cm.jet(cam[i])[..., :3] * 255)
    ax[i].imshow(images[i])
    ax[i].imshow(heatmap, cmap='jet', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated function (or staticmethod) normalize. (Inappropriate naming, Use `standardize()` instead.) -- Deprecated since version 0.6.0.
#   # Remove the CWD from sys.path while we load stuff.

# %%
ins = np.asarray([np.array(testX[correct[6]]), np.array(testX[correct[7]])])
S = preprocess_input(images)

# Render
subprot_args = {
    'nrows': 1,
    'ncols': 2,
    'figsize': (8, 4),
    'subplot_kw': {'xticks': [], 'yticks': []}
}
f, ax = plt.subplots(**subprot_args)
for i in range(len(ins)):
    ax[i].imshow(ins[i])
plt.tight_layout()
plt.show()

# %%
from matplotlib import cm
from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.utils import normalize

# Create Gradcam object
gradcam = Gradcam(model, model_modifier, clone=False)

# Generate heatmap with GradCAM
cam = gradcam(loss, S)
cam = normalize(cam)

f, ax = plt.subplots(**subprot_args)
for i in range(len(cam)):
    heatmap = np.uint8(cm.jet(cam[i])[..., :3] * 255)
    ax[i].imshow(ins[i])
    ax[i].imshow(heatmap, cmap='jet', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated function (or staticmethod) normalize. (Inappropriate naming, Use `standardize()` instead.) -- Deprecated since version 0.6.0.
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-8c3bd45f3bc0> in <module>
#      13 for i in range(len(cam)):
#      14     heatmap = np.uint8(cm.jet(cam[i])[..., :3] * 255)
# ---> 15     ax[i].imshow(ins[i])
#      16     ax[i].imshow(heatmap, cmap='jet', alpha=0.5)
#      17 plt.tight_layout()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# ## Saliency Maps

# %%
from tf_keras_vis.saliency import Saliency
from tf_keras_vis.utils import normalize

# Create Saliency object
saliency = Saliency(model, model_modifier, clone=False)

# Generate saliency map
saliency_map = saliency(loss, S)
saliency_map = normalize(saliency_map)

f, ax = plt.subplots(**subprot_args)
for i in range(len(saliency_map)):
    ax[i].imshow(saliency_map[i], cmap='jet')
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated function (or staticmethod) normalize. (Inappropriate naming, Use `standardize()` instead.) -- Deprecated since version 0.6.0.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-f040c4d50f21> in <module>
#      11 f, ax = plt.subplots(**subprot_args)
#      12 for i in range(len(saliency_map)):
# ---> 13     ax[i].imshow(saliency_map[i], cmap='jet')
#      14 plt.tight_layout()
#      15 plt.show()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
# Generate saliency map with smoothing that reduce noise by adding noise
saliency_map = saliency(loss, S, smooth_samples=100)
saliency_map = normalize(saliency_map)

f, ax = plt.subplots(**subprot_args)
for i in range(len(saliency_map)):
    ax[i].imshow(saliency_map[i], cmap='jet')
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated function (or staticmethod) normalize. (Inappropriate naming, Use `standardize()` instead.) -- Deprecated since version 0.6.0.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-c780cb401bd8> in <module>
#       5 f, ax = plt.subplots(**subprot_args)
#       6 for i in range(len(saliency_map)):
# ----> 7     ax[i].imshow(saliency_map[i], cmap='jet')
#       8 plt.tight_layout()
#       9 plt.show()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

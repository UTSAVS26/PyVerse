# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./DATA/forestcleaned.csv')

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data.head()
# Out:
#    X  Y  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area  month  day
# 0  7  5  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0      3    5
# 1  7  4  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0     10    2
# 2  7  4  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0     10    6
# 3  8  6  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0      3    5
# 4  8  6  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0      3    7

# %%
duplicates = data.duplicated().sum()

# %%
duplicates
# Out:
# 4

# %%
missing_values = data_cleaned.isnull().sum()

# %%
missing_values
# Out:
# X        0
# Y        0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# month    0
# day      0
# dtype: int64

# %%
data_types = data.dtypes

# %%
data_types
# Out:
# X          int64
# Y          int64
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# month      int64
# day        int64
# dtype: object

# %%
data = data.drop_duplicates()

# %%
numerical_features = data.select_dtypes(include=[np.number]).columns.tolist()

# %%
numerical_features
# Out:
# ['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']

# %%
scaler = StandardScaler()
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# %%
z_scores = np.abs(stats.zscore(data[numerical_features]))

# %%
z_scores
# Out:
#             X         Y      FFMC       DMC        DC       ISI      temp  \
# 0    1.001657  0.569075  0.801628  1.322179  1.837925  0.858350  1.835573
# 1    1.001657  0.244116  0.006761  1.178717  0.484659  0.508323  0.152432
# 2    1.001657  0.244116  0.006761  1.049290  0.556583  0.508323  0.736379
# 3    1.433101  1.382265  0.191956  1.211464  1.905808  0.005160  1.818399
# 4    1.433101  1.382265  0.241608  0.930777  1.806003  0.126100  1.285976
# ..        ...       ...       ...       ...       ...       ...       ...
# 512  0.292676  1.057306  1.632626  0.846571  0.470516  1.558403  1.530710
# 513  1.155564  0.244116  1.632626  0.846571  0.470516  1.558403  0.517390
# 514  1.001657  0.244116  1.632626  0.846571  0.470516  1.558403  0.397166
# 515  1.587008  0.244116  0.679715  0.545947  0.264846  0.498003  1.152862
# 516  0.570213  1.057306  2.011994  1.683954  1.787820  1.733416  1.217276
#
#            RH      wind      rain      area
# 0    0.406971  1.498430  0.073555  0.201967
# 1    0.694428  1.733018  0.073555  0.201967
# 2    0.694428  1.510159  0.073555  0.201967
# 3    3.221658  0.005865  0.600261  0.201967
# 4    3.344035  1.231586  0.073555  0.201967
# ..        ...       ...       ...       ...
# 512  0.755617  0.730155  0.073555  0.101074
# 513  1.630748  0.996998  0.073555  0.648570
# 514  1.569559  1.498430  0.073555  0.027128
# 515  0.143728  0.005865  0.073555  0.201967
# 516  0.816805  0.272708  0.073555  0.201967
#
# [513 rows x 11 columns]

# %%
outliers = (z_scores > 3).sum()

# %%
threshold = 3
outlier_mask = (z_scores > threshold).any(axis=1)
outliers = data[outlier_mask]

# %%
outliers.loc[:, 'num_outliers'] = (z_scores[outlier_mask] > threshold).sum(axis=1)

# %%
outliers
# Out:
#             X         Y       FFMC       DMC        DC        ISI      temp  \
# 3    1.433101  1.382265   0.191956 -1.211464 -1.905808  -0.005160 -1.818399
# 4    1.433101  1.382265  -0.241608 -0.930777 -1.806003   0.126100 -1.285976
# 12   0.570213  0.569075  -4.902419 -0.626700  0.469304  -1.799046 -0.324181
# 22   1.001657 -0.244116   0.661650 -0.229060 -1.410825  10.298748  0.362816
# 75   1.864545  3.821836  -1.162931 -1.624697 -2.111479  -0.289557 -2.093197
# 76   1.864545  3.821836  -0.729368 -1.524898 -2.045212  -0.814596 -0.547455
# 97  -0.724120 -0.244116  -3.908836 -1.693310 -2.156330  -1.820923 -0.255481
# 130 -0.292676  1.382265  -4.053357 -1.395470 -1.866614  -1.799046 -0.598979
# 138  1.864545  3.821836  -0.873889 -0.977558 -0.952611  -1.120870 -0.152432
# 151  1.864545  3.821836  -0.097087 -0.661006 -0.783711  -0.398940  1.015463
# 168  0.570213  0.569075   0.101630 -0.977558 -1.823782   0.760523 -0.736379
# 199 -1.155564 -0.244116  -4.902419 -0.626700  0.469304  -1.799046  0.637615
# 211  1.001657 -0.244116   0.517128  0.443029  0.182012   2.466903 -2.367996
# 237 -1.587008 -1.870496   0.065499  0.288651  0.579615  -0.442693 -0.015032
# 238  0.570213  0.569075   0.336477  0.157664  0.506074  -0.092667  1.066988
# 243  1.001657 -0.244116   0.210021  0.999724  0.612344   1.044920  0.517390
# 299  0.570213  0.569075  -6.727000 -0.623581 -1.274250  -1.886553 -1.423375
# 304  0.570213  0.569075  -1.000345 -1.294111 -1.759131  -1.208376 -1.303151
# 312 -1.155564 -0.244116  -7.268955 -1.010305  0.636184  -1.886553 -1.148577
# 379 -0.292676  0.569075 -12.995610 -1.713582 -1.526388  -1.974060 -2.350821
# 402  1.864545  3.821836   0.751975  1.809038  0.636588   0.651140  1.049813
# 411  1.001657 -0.244116  -1.090671 -1.680835 -2.042787  -1.252130 -1.835573
# 415  1.433101  1.382265   0.751975  1.737307  0.603859   1.066796  1.479186
# 420  1.433101  3.008646   0.191956  1.253902  0.350508  -0.267680  1.255912
# 469  0.570213 -1.057306   0.065499 -1.503067 -2.115519   0.716770 -0.890953
# 475 -1.155564  0.569075   0.553259  0.167020 -0.803914   1.963740  0.654790
# 479  1.001657 -0.244116  -0.259673 -0.110548 -0.475003  -0.573953  0.637615
# 480  1.864545  3.821836   0.462933  0.053186  0.043821   0.104223  1.942908
# 499  1.001657  0.569075   0.986823  1.093286  0.493144   1.154303  1.444836
# 509  0.138769 -0.244116   0.065499  0.871856  0.822056  -0.420817  0.379991
#
#            RH      wind       rain       area month day  num_outliers
# 3    3.221658 -0.005865   0.600261  -0.201967     3   5             1
# 4    3.344035 -1.231586  -0.073555  -0.201967     3   7             1
# 12   1.691937  1.498430  -0.073555  -0.201967     8   5             1
# 22  -0.021350  0.272708  -0.073555  -0.201967     6   7             1
# 75   2.120259 -0.507296  -0.073555  -0.201967     2   4             1
# 76  -0.082539 -0.507296  -0.073555  -0.201967     2   5             1
# 97  -1.245127  0.774140  -0.073555  -0.201967     3   6             1
# 130 -0.266106 -0.730155  -0.073555  -0.201967     2   6             1
# 138 -0.143728 -0.730155  -0.073555  -0.196327     7   2             1
# 151 -0.939183 -1.008728  -0.073555  -0.180660     7   7             1
# 168 -1.122750  3.002725  -0.073555  -0.162330     3   5             1
# 199 -0.388483 -0.228723  -0.073555  -0.024622     9   1             1
# 211  3.160469  0.996998  -0.073555   0.205363     8   6             1
# 237 -0.266106 -1.008728  -0.073555   3.133127     9   2             1
# 238 -1.061561 -0.005865  -0.073555  16.887727     9   6             1
# 243  1.753126  1.999861   3.295524  -0.201967     8   7             1
# 299  2.793336 -0.730155  -0.073555  -0.201967     6   6             1
# 304  3.038091  0.495567  -0.073555  -0.201967     5   6             1
# 312  2.059070  1.275571  -0.073555  -0.201967     9   7             1
# 379  3.405224 -1.733018  -0.073555  -0.201967     1   7             2
# 402 -0.510861 -0.005865  -0.073555  -0.201967     8   5             1
# 411  0.529349  3.002725  -0.073555  -0.129587     2   5             1
# 415 -1.061561  0.495567  -0.073555  11.489663     8   4             1
# 420 -0.510861  0.272708  -0.073555   2.708251     8   3             1
# 469 -0.694428  3.002725  -0.073555   0.755729     4   7             1
# 475 -0.266106  3.002725  -0.073555  -0.151991     6   4             1
# 479  0.774104  0.495567  -0.073555   4.161636     7   1             1
# 480 -1.183938  0.272708  -0.073555  -0.158884     7   4             1
# 499  1.141237  0.495567  21.488551  -0.032455     8   2             1
# 509  1.630748  1.999861   4.643156  -0.167970     8   5             1

# %%
outliers = outliers.drop(index=379)

# %%
len(outliers)
# Out:
# 29

# %%
df_cleaned = data[~outlier_mask].copy()
# Out:
# C:\Windows\Temp\ipykernel_3968\804328076.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned = data[~outlier_mask].copy()

# %%
df_cleaned.head()
# Out:
#           X         Y      FFMC       DMC        DC       ISI      temp  \
# 0  1.001657  0.569075 -0.801628 -1.322179 -1.837925 -0.858350 -1.835573
# 1  1.001657 -0.244116 -0.006761 -1.178717  0.484659 -0.508323 -0.152432
# 2  1.001657 -0.244116 -0.006761 -1.049290  0.556583 -0.508323 -0.736379
# 5  1.433101  1.382265  0.300346 -0.400591 -0.247109  1.241810  0.568915
# 6  1.433101  1.382265  0.300346 -0.344454 -0.216399 -0.114543  0.895238
#
#          RH      wind      rain      area month day
# 0  0.406971  1.498430 -0.073555 -0.201967     3   5
# 1 -0.694428 -1.733018 -0.073555 -0.201967    10   2
# 2 -0.694428 -1.510159 -0.073555 -0.201967    10   6
# 5 -0.939183  0.774140 -0.073555 -0.201967     8   7
# 6 -1.061561 -0.507296 -0.073555 -0.201967     8   1

# %%
# Out:
# 483

# %%
# Out:
# 0.9342359767891683

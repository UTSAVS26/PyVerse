# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense

# %%
data = pd.read_csv('C:\\Contributions\Programs\\ML_DL\\Medical_diagnoser\\Dataset\\medical_data.csv')
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\billa\AppData\Local\Temp\ipykernel_34220\1807089392.py:1: SyntaxWarning: invalid escape sequence '\P'
#   data = pd.read_csv('C:\\Contributions\Programs\\ML_DL\\Medical_diagnoser\\Dataset\\medical_data.csv')
#                                      Patient_Problem  \
# 0  Constant fatigue and muscle weakness, struggli...
# 1  Frequent severe migraines, sensitivity to ligh...
# 2  Sudden weight gain and feeling cold, especiall...
# 3  High fever, sore throat, and swollen lymph nod...
# 4  Excessive thirst and frequent urination, dry m...
#
#                     Disease                                       Prescription
# 0  Chronic Fatigue Syndrome  Cognitive behavioral therapy, graded exercise ...
# 1        Migraine with Aura  Prescription triptans, avoid triggers like bri...
# 2            Hypothyroidism  Levothyroxine to regulate thyroid hormone levels.
# 3             Mononucleosis            Rest and hydration, ibuprofen for pain.
# 4         Diabetes Mellitus             Insulin therapy and lifestyle changes.

# %%
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(data['Patient_Problem'])

sequences = tokenizer.texts_to_sequences(data['Patient_Problem'])

# %%
max_length = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# %%
# Encoding the labels
label_encoder_disease = LabelEncoder()
label_encoder_prescription = LabelEncoder()

disease_labels = label_encoder_disease.fit_transform(data['Disease'])
prescription_labels = label_encoder_prescription.fit_transform(data['Prescription'])

# Converting labels to categorical
disease_labels_categorical = to_categorical(disease_labels)
prescription_labels_categorical = to_categorical(prescription_labels)

# %%
Y = np.hstack((disease_labels_categorical, prescription_labels_categorical))

# %%
input_layer = Input(shape=(max_length,))

embedding = Embedding(input_dim=5000, output_dim=64)(input_layer)
lstm_layer = LSTM(64)(embedding)

disease_output = Dense(len(label_encoder_disease.classes_), activation='softmax', 
name='disease_output')(lstm_layer)

prescription_output = Dense(len(label_encoder_prescription.classes_), 
activation='softmax', name='prescription_output')(lstm_layer)

# %%
model = Model(inputs=input_layer, outputs=[disease_output, prescription_output])

model.compile(
    loss={'disease_output': 'categorical_crossentropy', 
    'prescription_output': 'categorical_crossentropy'},
    optimizer='adam',
    metrics={'disease_output': ['accuracy'], 'prescription_output': ['accuracy']}
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 17)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 17, 64)    │    320,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 64)        │     33,024 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ disease_output      │ (None, 178)       │     11,570 │ lstm[0][0]        │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prescription_output │ (None, 388)       │     25,220 │ lstm[0][0]        │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 389,814 (1.49 MB)
#  Trainable params: 389,814 (1.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(padded_sequences, {'disease_output': disease_labels_categorical, 'prescription_output':
      prescription_labels_categorical}, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - disease_output_accuracy: 0.0000e+00 - loss: 11.1431 - prescription_output_accuracy: 0.0039
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.0260 - loss: 11.1243 - prescription_output_accuracy: 0.0058
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.0259 - loss: 11.0825 - prescription_output_accuracy: 0.0164
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0434 - loss: 10.9096 - prescription_output_accuracy: 0.0162
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.0321 - loss: 10.8354 - prescription_output_accuracy: 0.0168
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.0402 - loss: 10.7843 - prescription_output_accuracy: 0.0091
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0376 - loss: 10.6485 - prescription_output_accuracy: 0.0188
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.0451 - loss: 10.4201 - prescription_output_accuracy: 0.0260
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0711 - loss: 10.1943 - prescription_output_accuracy: 0.0227
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.0602 - loss: 10.1019 - prescription_output_accuracy: 0.0212
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.0879 - loss: 9.7549 - prescription_output_accuracy: 0.0306
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.0854 - loss: 9.5883 - prescription_output_accuracy: 0.0154
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.1288 - loss: 9.2857 - prescription_output_accuracy: 0.0387
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.1553 - loss: 9.1685 - prescription_output_accuracy: 0.0296
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.1757 - loss: 8.9582 - prescription_output_accuracy: 0.0387
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2146 - loss: 8.6875 - prescription_output_accuracy: 0.0531
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.1927 - loss: 8.4945 - prescription_output_accuracy: 0.0417
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.2214 - loss: 8.3062 - prescription_output_accuracy: 0.0746
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2297 - loss: 8.0536 - prescription_output_accuracy: 0.0689
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.2705 - loss: 7.8162 - prescription_output_accuracy: 0.0845
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.2446 - loss: 7.6986 - prescription_output_accuracy: 0.1035
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2919 - loss: 7.3723 - prescription_output_accuracy: 0.1150
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.3218 - loss: 7.2233 - prescription_output_accuracy: 0.1053
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3149 - loss: 7.1186 - prescription_output_accuracy: 0.1331
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.3865 - loss: 6.7875 - prescription_output_accuracy: 0.1310
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3761 - loss: 6.7744 - prescription_output_accuracy: 0.1854
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3530 - loss: 6.5614 - prescription_output_accuracy: 0.1695
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.4003 - loss: 6.4604 - prescription_output_accuracy: 0.2084
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3916 - loss: 6.3135 - prescription_output_accuracy: 0.2078
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.4075 - loss: 6.3072 - prescription_output_accuracy: 0.1959
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.4393 - loss: 6.0614 - prescription_output_accuracy: 0.2242
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.4126 - loss: 6.0336 - prescription_output_accuracy: 0.2377
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.4877 - loss: 5.8556 - prescription_output_accuracy: 0.2729
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.4744 - loss: 5.7335 - prescription_output_accuracy: 0.2542
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - disease_output_accuracy: 0.5007 - loss: 5.5657 - prescription_output_accuracy: 0.2973
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5019 - loss: 5.5204 - prescription_output_accuracy: 0.2613
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5167 - loss: 5.3902 - prescription_output_accuracy: 0.3168
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.5353 - loss: 5.2524 - prescription_output_accuracy: 0.3589
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5532 - loss: 5.1766 - prescription_output_accuracy: 0.3756
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5338 - loss: 5.1755 - prescription_output_accuracy: 0.3212
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5643 - loss: 5.0073 - prescription_output_accuracy: 0.3423
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6278 - loss: 4.8640 - prescription_output_accuracy: 0.3646
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.5786 - loss: 4.8369 - prescription_output_accuracy: 0.3839
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6081 - loss: 4.7458 - prescription_output_accuracy: 0.4060
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.6449 - loss: 4.6080 - prescription_output_accuracy: 0.4533
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6665 - loss: 4.4863 - prescription_output_accuracy: 0.4651
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6454 - loss: 4.4354 - prescription_output_accuracy: 0.4614
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6561 - loss: 4.3757 - prescription_output_accuracy: 0.4899
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6490 - loss: 4.3628 - prescription_output_accuracy: 0.5005
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - disease_output_accuracy: 0.7152 - loss: 4.0624 - prescription_output_accuracy: 0.5544
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7120 - loss: 4.1001 - prescription_output_accuracy: 0.4938
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7320 - loss: 3.9553 - prescription_output_accuracy: 0.5935
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7547 - loss: 3.9348 - prescription_output_accuracy: 0.5618
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7461 - loss: 3.9299 - prescription_output_accuracy: 0.5273
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7268 - loss: 3.8954 - prescription_output_accuracy: 0.5873
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.7493 - loss: 3.8102 - prescription_output_accuracy: 0.5694
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.7081 - loss: 3.8103 - prescription_output_accuracy: 0.5575
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.7776 - loss: 3.6636 - prescription_output_accuracy: 0.6036
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.7897 - loss: 3.5791 - prescription_output_accuracy: 0.5962
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7939 - loss: 3.5476 - prescription_output_accuracy: 0.6191
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.7971 - loss: 3.5576 - prescription_output_accuracy: 0.5836
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.7812 - loss: 3.6732 - prescription_output_accuracy: 0.5882
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.7340 - loss: 3.5606 - prescription_output_accuracy: 0.5514
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - disease_output_accuracy: 0.7085 - loss: 3.8442 - prescription_output_accuracy: 0.4491
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.7387 - loss: 3.5261 - prescription_output_accuracy: 0.5590
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.7701 - loss: 3.5132 - prescription_output_accuracy: 0.5489
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.7659 - loss: 3.4330 - prescription_output_accuracy: 0.5781
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - disease_output_accuracy: 0.7967 - loss: 3.3818 - prescription_output_accuracy: 0.5519
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7956 - loss: 3.3028 - prescription_output_accuracy: 0.5908
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.7857 - loss: 3.2953 - prescription_output_accuracy: 0.5862
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7927 - loss: 3.2081 - prescription_output_accuracy: 0.6236
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - disease_output_accuracy: 0.8020 - loss: 3.0324 - prescription_output_accuracy: 0.6879
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8059 - loss: 3.1190 - prescription_output_accuracy: 0.6311
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8126 - loss: 2.9892 - prescription_output_accuracy: 0.6921
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8056 - loss: 2.9210 - prescription_output_accuracy: 0.6856
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - disease_output_accuracy: 0.8381 - loss: 2.9879 - prescription_output_accuracy: 0.6447
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8169 - loss: 2.9328 - prescription_output_accuracy: 0.6873
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8394 - loss: 2.7720 - prescription_output_accuracy: 0.7098
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8274 - loss: 2.8286 - prescription_output_accuracy: 0.6903
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8491 - loss: 2.6280 - prescription_output_accuracy: 0.6980
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8801 - loss: 2.6828 - prescription_output_accuracy: 0.6764
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.8671 - loss: 2.6761 - prescription_output_accuracy: 0.7056
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.8972 - loss: 2.4824 - prescription_output_accuracy: 0.7217
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8895 - loss: 2.4610 - prescription_output_accuracy: 0.7471
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8660 - loss: 2.4829 - prescription_output_accuracy: 0.7339
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.9034 - loss: 2.4150 - prescription_output_accuracy: 0.7469
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.9183 - loss: 2.3011 - prescription_output_accuracy: 0.7623
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.9061 - loss: 2.4114 - prescription_output_accuracy: 0.7599
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - disease_output_accuracy: 0.8722 - loss: 2.4036 - prescription_output_accuracy: 0.7419
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8836 - loss: 2.4200 - prescription_output_accuracy: 0.7459
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8853 - loss: 2.3399 - prescription_output_accuracy: 0.7677
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8770 - loss: 2.3379 - prescription_output_accuracy: 0.7547
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8882 - loss: 2.4070 - prescription_output_accuracy: 0.7086
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8527 - loss: 2.5037 - prescription_output_accuracy: 0.6434
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8734 - loss: 2.4460 - prescription_output_accuracy: 0.7550
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8827 - loss: 2.3375 - prescription_output_accuracy: 0.7119
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.8475 - loss: 2.4744 - prescription_output_accuracy: 0.7113
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8321 - loss: 2.4741 - prescription_output_accuracy: 0.6527
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - disease_output_accuracy: 0.8366 - loss: 2.4488 - prescription_output_accuracy: 0.6977
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.8492 - loss: 2.3740 - prescription_output_accuracy: 0.6872

# %%
def make_prediction(patient_problem):
    # Preprocessing the input
    sequence = tokenizer.texts_to_sequences([patient_problem])
    padded_sequence = pad_sequences(sequence, maxlen=max_length, padding='post')
    
    # Making prediction
    prediction = model.predict(padded_sequence)
    
    # Decoding the prediction
    disease_index = np.argmax(prediction[0], axis=1)[0]
    prescription_index = np.argmax(prediction[1], axis=1)[0]
    
    disease_predicted = label_encoder_disease.inverse_transform([disease_index])[0]
    prescription_predicted = label_encoder_prescription.inverse_transform([prescription_index])[0]
    
    print(f"Predicted Disease: {disease_predicted}")
    print(f"Suggested Prescription: {prescription_predicted}")


patient_input = "I played a lot and i cannot walk properly now."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Predicted Disease: Hyperthyroidism
# Suggested Prescription: Dietary iodine; consider thyroid hormone replacement therapy.
